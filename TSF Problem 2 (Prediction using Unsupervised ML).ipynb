# %% [markdown]
# # By:- Chirag Singh

# %% [markdown]
# ## The Sparks Foundation

# %% [markdown]
# ## Data Science & Business Analytics Intern¶

# %% [markdown]
# ### Prediction using Unsupervised ML

# %% [markdown]
# #### Problem Statement: predict the optimum number of clusters and represent it visually

# %% [markdown]
# ## Import libaries

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# %%
# Load the iris dataset
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)

# %%
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
# Finding the optimum number of clusters for k-means classification

x = iris_df.iloc[:, [0, 1, 2, 3]].values

# %%
from sklearn.cluster import KMeans
wcss = []

# %%
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# %%
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %%
tmp = iris_df
g = sns.pairplot(tmp, markers='+')
plt.show()

# %%
g = sns.violinplot(y='Species', x='sepal length (cm)', data=iris_df, inner='quartile')
plt.show()
g = sns.violinplot(y='Species', x='sepal width (cm)', data=iris_df, inner='quartile')
plt.show()
g = sns.violinplot(y='Species', x='petal length (cm)', data=iris_df, inner='quartile')
plt.show()
g = sns.violinplot(y='Species', x='petal width (cm)', data=iris_df, inner='quartile')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7234e8b6ee4e> in <module>
# ----> 1 g = sns.violinplot(y='Species', x='sepal length (cm)', data=iris_df, inner='quartile')
#       2 plt.show()
#       3 g = sns.violinplot(y='Species', x='sepal width (cm)', data=iris_df, inner='quartile')
#       4 plt.show()
#       5 g = sns.violinplot(y='Species', x='petal length (cm)', data=iris_df, inner='quartile')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2385                              bw, cut, scale, scale_hue, gridsize,
#    2386                              width, inner, split, dodge, orient, linewidth,
# -> 2387                              color, palette, saturation)
# ...

# %%
# Applying kmeans to the dataset / Creating the kmeans classifier
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %%
# Visualising the clusters - On the first two columns
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')
# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')
plt.legend()
